# %%
import pandas as pd

# %%
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",header=None)

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df=iris.copy() #dataframe

# %%
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head() #displays first 5 rows only
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
#changing column names
df.columns=['sl','sw','pl','pw','flower']
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower'], dtype='object')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sl        float64
# sw        float64
# pl        float64
# pw        float64
# flower     object
# dtype: object

# %%
#describe
df.describe()
# Out:
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#describe
df.describe(include='all') #includes not just numbers but also objects
# Out:
#                 sl          sw          pl          pw       flower
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
df['sl'] #only displays one column
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df.sl.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sl, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower
# 0    False  False  False  False   False
# 1    False  False  False  False   False
# 2    False  False  False  False   False
# 3    False  False  False  False   False
# 4    False  False  False  False   False
# ..     ...    ...    ...    ...     ...
# 145  False  False  False  False   False
# 146  False  False  False  False   False
# 147  False  False  False  False   False
# 148  False  False  False  False   False
# 149  False  False  False  False   False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl        0
# sw        0
# pl        0
# pw        0
# flower    0
# dtype: int64

# %%
#iloc
df.iloc[2:9,1:2] #rows 2 to 9, columns 1 to 2
# Out:
#     sw
# 2  3.2
# 3  3.1
# 4  3.6
# 5  3.9
# 6  3.4
# 7  3.4
# 8  2.9

# %%
df.drop(0,inplace=True) #drops row number 0
df
# Out:
#       sl   sw   pl   pw          flower
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.index[0]
# Out:
# 1

# %%
df.iloc[0]
# Out:
# sl                4.9
# sw                3.0
# pl                1.4
# pw                0.2
# flower    Iris-setosa
# Name: 1, dtype: object

# %%
df.loc[2] #second row
# Out:
# sl                4.7
# sw                3.2
# pl                1.3
# pw                0.2
# flower    Iris-setosa
# Name: 2, dtype: object

# %%
df.loc[0]=[1,2,3,4, "Iris-setosa"] #inserts row 0
df.tail() #displays last 5 rows
# Out:
#       sl   sw   pl   pw          flower
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa

# %%
df.drop('sl',axis=1,inplace=True) #drops a column
df.head()
# Out:
#     sw   pl   pw       flower
# 1  3.0  1.4  0.2  Iris-setosa
# 2  3.2  1.3  0.2  Iris-setosa
# 3  3.1  1.5  0.2  Iris-setosa
# 4  3.6  1.4  0.2  Iris-setosa
# 5  3.9  1.7  0.4  Iris-setosa

# %%
df['diff_pl_pw'] = df['pl']-df['pw'] #adds a new column
df.head()
# Out:
#     sw   pl   pw       flower  diff_pl_pw
# 1  3.0  1.4  0.2  Iris-setosa         1.2
# 2  3.2  1.3  0.2  Iris-setosa         1.1
# 3  3.1  1.5  0.2  Iris-setosa         1.3
# 4  3.6  1.4  0.2  Iris-setosa         1.2
# 5  3.9  1.7  0.4  Iris-setosa         1.3

# %%
df=iris.copy() #restore data after analysis
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]
