# %%
print("Hello World")
# Out:
# Hello World

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
a=1
b=1.2
c='A'
d="Shyam"
e="Python"
print(type(a), type(b), type(c))
print(type(d), type(e))
# Out:
# <class 'int'> <class 'float'> <class 'str'>
# <class 'str'> <class 'str'>

# %%
a = input("What is your name?")
print("My name is ", a)
# Out:
# What is your name?Adi
# My name is  Adi

# %%
p = int(input("Enter First Number"))
q = int(input("Enter Second Number"))
r = p+q
print("Sum = ", r)
# Out:
# Enter First Number2
# Enter Second Number3
# Sum =  5

# %%
p = int(input("Enter First Number"))
q = int(input("Enter Second Number"))
r = p+q
print("Sum of ", p, " and ", q, " = " , r)
print(f"Sum of {p} and {q} is {r}")
# Out:
# Enter First Number4
# Enter Second Number5
# Sum of  4  and  5  =  9
# Sum of 4 and 5 is 9

# %%
print(10>9)
print(20==21)
# Out:
# True
# False

# %%
a=22
b=12
if(b>a):
    print("b is greater than a")
else:
    print("b is smaller than a")
# Out:
# b is smaller than a

# %%
a=22
b=22
if(b>a):
    print("b is greater than a")
elif(a==b):
    print("b is equal to a")
else:
    print("b is smaller than a")
# Out:
# b is equal to a

# %%
names = ["Shyam", "Rahul", "Rishi", "Adi", "Arno"]
for x in names:
    print(x)
# Out:
# Shyam
# Rahul
# Rishi
# Adi
# Arno

# %%
def my_function():
    print("Hello from function");

my_function()
my_function()
# Out:
# Hello from function
# Hello from function

# %%
def my_function(n):
    print(n+3)

my_function(5)
my_function(7)
# Out:
# 8
# 10
