# %%
import numpy as np

# %%
a=np.array([1,2,3])
b=np.array([3,8,7])

# %%
print(a+2)
# Out:
# [3 4 5]

# %%
print(a+b)
# Out:
# [ 4 10 10]

# %%
print(a**2)
# Out:
# [1 4 9]

# %%
print(a**b)
# Out:
# [   1  256 2187]

# %%
a.mean()
# Out:
# 2.0

# %%
a.sum()
# Out:
# 6

# %%
b.sum()
# Out:
# 18

# %%
#visit numpy.org for more array operations
